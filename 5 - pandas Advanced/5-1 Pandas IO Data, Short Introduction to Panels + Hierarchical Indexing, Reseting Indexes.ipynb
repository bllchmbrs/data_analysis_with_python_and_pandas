# %%
# %matplotlib inline
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'
print sys.version
print "Pandas:", pd.version.version
# Out:
# 2.7.6 (default, Sep  9 2014, 15:04:36)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.39)]
# Pandas: 0.15.0

# %% [markdown]
# In this section we will be analyzing some financial data. Now pandas gives us access to some data through pandas.io.data
#
# This is basically pandas remote data access:
# http://pandas.pydata.org/pandas-docs/stable/remote_data.html
#
# Functions from pandas.io.data and pandas.io.ga extract data from various Internet sources into a DataFrame. Currently the following sources are supported:
#
# - Yahoo! Finance
# - Google Finance
# - St.Louis FED (FRED)
# - Kenneth French’s data library
# - World Bank
# - Google Analytics
#
# So let’s grab some  stocks from yahoo data with pandas.io.data. I've seen this list actively change so it's a good idea to see what is available to you - there's likely some really cool plugins that will continue to be built.

# %%
import pandas.io.data

# %%
# ?pandas.io.data # <tab>

# %% [markdown]
# Now there’s a lot of volatility in oil right now. It’s been rough for producers to say the least. So let’s check out some stocks that are involved in that market.
#
# First we’ll set start and end dates these are just date times. Now I can do this with date times in python but I can also just get a datetime with pandas which can parse a string to pull out a date time. This ends up being pretty handy.

# %%
import datetime
print datetime.datetime(2010,1,1)
# Out:
# 2010-01-01 00:00:00

# %% [markdown]
# WTI which is W&T Offshore Inc. They drill in the gulf of Mexico.
#
# Let’s also check out
#
# CHK or Chesapeake Energy Corporation.
#
# Tesla Motors
#
# and finally CBAK which is China Bak Battery Incorporated.

# %%
start = pd.to_datetime('2010-1-1')
end = datetime.datetime(2015,1,1)
ticker_symbols = ['WTI','CHK','TSLA','CBAK']

# %%
wti = pd.io.data.get_data_yahoo(ticker_symbols[0],start=start,end=end)

# %%
wti.head()
# Out:
#              Open   High    Low  Close  Volume  Adj Close
# Date
# 2010-01-04  11.90  12.46  11.86  12.26  838800       9.82
# 2010-01-05  12.30  12.63  12.17  12.34  625400       9.89
# 2010-01-06  12.41  12.65  12.39  12.58  604700      10.08
# 2010-01-07  12.60  12.70  12.24  12.45  565300       9.98
# 2010-01-08  12.37  12.54  12.12  12.50  521100      10.02

# %% [markdown]
# Now we can get these one by one in a for loop...

# %%
for symbol in ticker_symbols:
    print symbol
    df = pd.io.data.get_data_yahoo(symbol,start=start,end=end)
# Out:
# WTI
# CHK
# TSLA
# CBAK

# %% [markdown]
# or we can just get them all by passing in the list....

# %%
panl = pd.io.data.get_data_yahoo(ticker_symbols,start=start,end=end)

# %% [markdown]
# But we get something different back that we haven’t encountered yet. This is a panel. Now panels are advanced and explaining their use case is outside of this video. However, I’ll give you the basics.

# %% [markdown]
# Panels are 3 dimensional containers that we can query on each of those dimensions.

# %%
panl
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 1258 (major_axis) x 4 (minor_axis)
# Items axis: Open to Adj Close
# Major_axis axis: 2010-01-04 00:00:00 to 2014-12-31 00:00:00
# Minor_axis axis: CBAK to WTI

# %% [markdown]
# We can see they’ve got an items axis, a major axis and a minor axis. Panels are a core part of pandas however they are much less used in pandas and therefore are a bit neglected as of now. That’s not just me trying to avoid the topic - which would be my suspicion if I heard that. But that ’s stated almost verbatim in the docs.
#
# http://pandas-docs.github.io/pandas-docs-travis/dsintro.html#from-dataframe-using-to-panel-method

# %%
type(panl)
# Out:
# pandas.core.panel.Panel

# %% [markdown]
# However let’s touch on the basis because you may come across them.
#
#
# We've got a lot of the basic methods like shape.

# %%
panl.shape
# Out:
# (6, 1258, 4)

# %% [markdown]
# We’ve got these three axes so we want to query data in them. We've got to do that a bit differently.
#
# Since we know these axis values we can query them.
#
# Now items are done like standard DataFrame columns with dot syntax.

# %%
panl.Open.head()
# Out:
#             CBAK    CHK  TSLA    WTI
# Date
# 2010-01-04  2.90  27.43   NaN  11.90
# 2010-01-05  2.72  28.30   NaN  12.30
# 2010-01-06  2.98  29.21   NaN  12.41
# 2010-01-07  2.90  28.63   NaN  12.60
# 2010-01-08  2.90  28.39   NaN  12.37

# %% [markdown]
# The major and minor axises are done differently. with the major_xs and minor_xs commands.

# %%
panl.major_xs('2013-5-1')
# Out:
#        Open   High    Low  Close    Volume  Adj Close
# CBAK   0.62   0.79   0.60   0.77     56800       0.77
# CHK   19.90  19.98  18.86  19.19  17267300      17.76
# TSLA  55.99  55.99  53.00  53.28   2742800      53.28
# WTI   11.54  11.54  11.03  11.22    720500      10.39

# %%
panl.minor_xs('CHK').head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2010-01-04  27.43  28.11  26.92  28.09  31146800      24.77
# 2010-01-05  28.30  29.12  28.20  28.97  28692700      25.55
# 2010-01-06  29.21  29.22  28.53  28.65  16055000      25.26
# 2010-01-07  28.63  28.80  28.18  28.72  13906600      25.33
# 2010-01-08  28.39  28.92  28.05  28.91  11656400      25.49

# %% [markdown]
# Some summary statistics are available to us like mean on the panel.

# %%
panl.mean()
# Out:
#            Open       High        Low      Close           Volume  Adj Close
# CBAK   1.729793   1.801296   1.670548   1.726312    117231.399046   4.791431
# CHK   24.194173  24.530962  23.802099  24.165183  14230063.910970  22.160851
# TSLA  88.219516  89.988011  86.329129  88.177227   4133400.176056  88.177227
# WTI   16.080199  16.418887  15.720723  16.069173    806965.580286  14.329173

# %% [markdown]
# We can perform different kinds of selections and transposition using the major and minor axes however as I said above I'm not going to cover this material. However I’m going to convert this panel to a data frame to show you how to do that and in the process and we’re going to cover a new topic!

# %% [markdown]
# Now when we convert the panel to a data frame with the to_frame command - we can see it looks a bit different.

# %%
df = panl.to_frame()
df.head()
# Out:
#                    Open   High    Low  Close    Volume  Adj Close
# Date       minor
# 2010-01-04 CBAK    2.90   2.90   2.67   2.70    456600      13.50
#            CHK    27.43  28.11  26.92  28.09  31146800      24.65
#            WTI    11.90  12.46  11.86  12.26    838800       9.82
# 2010-01-05 CBAK    2.72   3.10   2.69   2.85   1179500      14.25
# %%
print len(df.index.levels)
# Out:
# 2

# %% [markdown]
# Alright we have our dataset in a hierarchical index. but that's not what we want to work with right now which will likely come up when you're analyzing data - you'll want to completely reset your index. Well have no fear, we can do that with the reset index command.
#
# You may find yourself using this often just to get back to square one and start over when performing analysis.

# %%
df.reset_index()
# Out:
#            Date minor    Open    High     Low   Close    Volume  Adj Close
# 0    2010-01-04  CBAK    2.90    2.90    2.67    2.70    456600      13.50
# 1    2010-01-04   CHK   27.43   28.11   26.92   28.09  31146800      24.65
# 2    2010-01-04   WTI   11.90   12.46   11.86   12.26    838800       9.82
# 3    2010-01-05  CBAK    2.72    3.10    2.69    2.85   1179500      14.25
# 4    2010-01-05   CHK   28.30   29.12   28.20   28.97  28692700      25.42
# 5    2010-01-05   WTI   12.30   12.63   12.17   12.34    625400       9.89
# 6    2010-01-06  CBAK    2.98    3.05    2.85    2.88    633500      14.40
# 7    2010-01-06   CHK   29.21   29.22   28.53   28.65  16055000      25.14
# 8    2010-01-06   WTI   12.41   12.65   12.39   12.58    604700      10.08
# 9    2010-01-07  CBAK    2.90    3.09    2.78    2.90    784600      14.50
# 10   2010-01-07   CHK   28.63   28.80   28.18   28.72  13906600      25.20
# 11   2010-01-07   WTI   12.60   12.70   12.24   12.45    565300       9.98
# 12   2010-01-08  CBAK    2.90    3.14    2.87    3.04    797800      15.20
# 13   2010-01-08   CHK   28.39   28.92   28.05   28.91  11656400      25.37
# 14   2010-01-08   WTI   12.37   12.54   12.12   12.50    521100      10.02
# 15   2010-01-11  CBAK    3.11    3.17    3.03    3.06    510100      15.30
# 16   2010-01-11   CHK   28.98   28.98   27.73   28.00  15041300      24.57
# 17   2010-01-11   WTI   12.65   13.27   12.14   12.40   1177400       9.94
# 18   2010-01-12  CBAK    3.08    3.08    2.90    2.92    383800      14.60
# 19   2010-01-12   CHK   27.51   27.70   27.17   27.58  13724400      24.20
# 20   2010-01-12   WTI   12.33   12.43   11.80   11.90    921200       9.54
# 21   2010-01-13  CBAK    2.92    3.02    2.91    2.94    276000      14.70
# 22   2010-01-13   CHK   27.42   27.94   26.92   27.82  11103000      24.41
# 23   2010-01-13   WTI   11.97   12.00   11.36   11.42   1778300       9.15
# 24   2010-01-14  CBAK    3.04    3.04    2.90    2.92    186800      14.60
# 25   2010-01-14   CHK   28.02   28.38   27.52   27.67  16784700      24.28
# 26   2010-01-14   WTI   11.42   11.90   11.42   11.80    890300       9.46
# 27   2010-01-15  CBAK    2.93    2.95    2.81    2.85    226100      14.25
# 28   2010-01-15   CHK   27.52   28.09   27.25   27.91  18228400      24.49
# 29   2010-01-15   WTI   11.82   11.86   11.00   11.10   2163400       8.90
# ...         ...   ...     ...     ...     ...     ...       ...        ...
# 4880 2014-12-19  TSLA  220.19  220.40  214.50  219.29   6890600     219.29
# 4881 2014-12-19   WTI    6.80    7.88    6.75    7.63   5775100       7.63
# 4882 2014-12-22  CBAK    1.92    1.93    1.88    1.91     24100       1.91
# 4883 2014-12-22   CHK   19.00   19.20   18.30   18.42  20323700      18.33
# 4884 2014-12-22  TSLA  220.00  224.06  218.26  222.60   4799400     222.60
# 4885 2014-12-22   WTI    7.46    7.69    6.99    7.52   2758500       7.52
# 4886 2014-12-23  CBAK    1.95    2.35    1.95    1.98    103100       1.98
# 4887 2014-12-23   CHK   19.43   20.35   19.20   20.29  21976500      20.19
# 4888 2014-12-23  TSLA  223.81  224.32  219.52  220.97   4505700     220.97
# 4889 2014-12-23   WTI    7.61    7.95    7.56    7.67   2856200       7.67
# 4890 2014-12-24  CBAK    1.95    1.96    1.89    1.93      7400       1.93
# 4891 2014-12-24   CHK   20.19   20.29   19.60   19.84   7504400      19.74
# 4892 2014-12-24  TSLA  219.77  222.50  219.25  222.26   1332200     222.26
# 4893 2014-12-24   WTI    7.51    7.83    7.42    7.55   1098500       7.55
# 4894 2014-12-26  CBAK    1.97    1.98    1.87    1.89     24900       1.89
# 4895 2014-12-26   CHK   20.00   20.18   19.50   19.71   7746500      19.61
# 4896 2014-12-26  TSLA  221.51  228.50  221.50  227.82   3299500     227.82
# 4897 2014-12-26   WTI    7.61    7.79    7.37    7.49   1154900       7.49
# 4898 2014-12-29  CBAK    1.89    1.97    1.82    1.94     42100       1.94
# 4899 2014-12-29   CHK   20.00   20.16   19.80   20.01   9109900      19.91
# 4900 2014-12-29  TSLA  226.90  227.91  224.02  225.71   2802500     225.71
# 4901 2014-12-29   WTI    7.65    7.87    7.53    7.72   1592400       7.72
# 4902 2014-12-30  CBAK    1.96    1.96    1.96    1.96         0       1.96
# 4903 2014-12-30   CHK   19.80   20.08   19.51   19.64   9890600      19.54
# 4904 2014-12-30  TSLA  224.78  225.55  221.43  222.13     91500     222.13
# 4905 2014-12-30   WTI    7.60    7.79    7.43    7.43   1106000       7.43
# 4906 2014-12-31  CBAK    1.84    1.92    1.83    1.85     76200       1.85
# 4907 2014-12-31   CHK   19.46   19.99   19.23   19.57  10677900      19.47
# 4908 2014-12-31  TSLA  223.09  225.68  222.25  222.41   2297500     222.41
# 4909 2014-12-31   WTI    7.29    7.44    6.94    7.34   1434700       7.34
#
# [4910 rows x 8 columns]

# %%
df.reset_index(inplace=True)

# %% [markdown]
# Now we've reset our index. Now I don't want to work with this data set as I'm not an expert on financial data however we'll be working with a really cool data set in our next video. We'll be working with an airplane data set that has flights across the country. This is going to give us the opportunity to work on a ton of cool problems.

# %%
df
