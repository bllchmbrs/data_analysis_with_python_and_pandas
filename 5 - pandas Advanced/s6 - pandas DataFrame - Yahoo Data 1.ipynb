# %% [markdown]
# In this section we will be analyzing some financial data. Now pandas gives us access to some data through pandas.io.data
#
# So let’s grab some  stocks from pandas.io.data.
#
# Now there’s a lot of volatility in oil right now. It’s been rough for producers to say the least. So let’s check out some stocks that are involved in that market.
#
# First we’ll set start and end dates these are just date times. Now I can do this with date times in python but I can also just get a datetime with pandas which can parse a string to pull out a date time. This ends up being pretty handy.
#
# WTI which is W&T Offshore Inc. They drill in the gulf of Mexico.
#
# Let’s also check out
#
# CHK or Chesapeake Energy Corporation.
#
# Tesla Motors
#
# and finally CBAK which is China Bak Battery Incorporated.
#
# Now we can get these one by one in a for loop or we can just get them all by passing in the list. But we get something different back that we haven’t encountered yet. This is a panel. Now panels are advanced and explaining their use case is outside of this video. However, I’ll give you the basics.
#
# Panels are 3 dimensional containers that we can query on each of those dimensions.
#
# We can see they’ve got an items axis, a major axis and a minor axis. Panels are a core part of pandas however they are much less used in pandas and therefore are a bit neglected as of now. That’s not just me trying to avoid the topic - which would be my suspicion if I heard that. But that ’s stated almost verbatim in the docs.
#
# http://pandas-docs.github.io/pandas-docs-travis/dsintro.html#from-dataframe-using-to-panel-method
#
# However let’s touch on the basis because you may come across them.
#
# We’ve got these three axes so we want to query data in them.
#
# Since we know these axis values we can query them.
#
# Now items are done like standard DataFrame columns with dot syntax.
#
# The major and minor axises are done differently. with the major_xs and minor_xs commands.
#
# Some summary statistics are available to us like mean. We can perform different kinds of selections and transposition. However I’m going to convert this panel to a data frame and we’re going to cover a new topic by doing so!
#
# Now when we convert the panel to a data frame with the to_frame command.
#
# But when we use the head method to see the first 5 we see things are a little different and that’s because we now have multiple indices or a hierarchical or multi index. Now hierarchical indexes are extremely powerful but they’re beyond the scope of this current video.
#
# In this next video we’ll dive a bit deeper into this dataset.
#
#
#
# Alright we have our dataset in a hierarchical index. Now that’s what we’re going to be working with in this section so I wanted to show you how you can start over with indexing. We do that with the reset index command, which will, you guessed it, reset our indeces.
#
# Now we've got our clean dataset with no indexes. Let’s learn something new, the groupby method.
#
# This method
#
# http://nbviewer.ipython.org/github/twiecki/financial-analysis-python-tutorial/blob/master/1.%20Pandas%20Basics.ipynb
#
#
#
# we need to look at biggest jumps for the day. or 10 biggest jumps. Biggest drops, maybe just biggest changes.

# %%
# %matplotlib inline
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'
print sys.version
print "Pandas:", pd.version.version
# Out:
# 2.7.6 (default, Sep  9 2014, 15:04:36)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.39)]
# Pandas: 0.15.0

# %%
import pandas.io.data

# %%
pandas.io.data. # <tab>
# Out:
#   File "<ipython-input-60-d45c1ded9aa5>", line 1
#     pandas.io.data. # <tab>
#                            ^
# SyntaxError: invalid syntax

# %%
import datetime
print datetime.datetime(2010,1,1)
# Out:
# 2010-01-01 00:00:00
# Timestamp('2010-01-01 00:00:00')

# %%
start = pd.to_datetime('2010-1-1')
end = datetime.datetime(2015,1,1)
ticker_symbols = ['WTI','CHK','TSLA','CBAK']

# %%
wti = pd.io.data.get_data_yahoo(ticker_symbols[0],start=start,end=end)

# %%
wti.head()
# Out:
#              Open   High    Low  Close  Volume  Adj Close
# Date
# 2010-01-04  11.90  12.46  11.86  12.26  838800       9.82
# 2010-01-05  12.30  12.63  12.17  12.34  625400       9.89
# 2010-01-06  12.41  12.65  12.39  12.58  604700      10.08
# 2010-01-07  12.60  12.70  12.24  12.45  565300       9.98
# 2010-01-08  12.37  12.54  12.12  12.50  521100      10.02

# %%
for symbol in ticker_symbols:
    print symbol
    df = pd.io.data.get_data_yahoo(symbol,start=start,end=end)
    df[['Open','Close']].plot(cmap='prism')
# Out:
# WTI
# CHK
# TSLA
# CBAK

# %%
panl = pd.io.data.get_data_yahoo(ticker_symbols,start=start,end=end)

# %%
panl
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 1258 (major_axis) x 4 (minor_axis)
# Items axis: Open to Adj Close
# Major_axis axis: 2010-01-04 00:00:00 to 2014-12-31 00:00:00
# Minor_axis axis: CBAK to WTI

# %%
type(panl)
# Out:
# pandas.core.panel.Panel

# %%
panl.shape
# Out:
# (6, 1258, 4)

# %%
panl.Open.head()
# Out:
#             CBAK    CHK  TSLA    WTI
# Date
# 2010-01-04  2.90  27.43   NaN  11.90
# 2010-01-05  2.72  28.30   NaN  12.30
# 2010-01-06  2.98  29.21   NaN  12.41
# 2010-01-07  2.90  28.63   NaN  12.60
# 2010-01-08  2.90  28.39   NaN  12.37

# %%
panl.major_xs('2013-5-1')
# Out:
#        Open   High    Low  Close    Volume  Adj Close
# CBAK   0.62   0.79   0.60   0.77     56800       0.77
# CHK   19.90  19.98  18.86  19.19  17267300      17.76
# TSLA  55.99  55.99  53.00  53.28   2742800      53.28
# WTI   11.54  11.54  11.03  11.22    720500      10.39

# %%
panl.minor_xs('CHK').head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2010-01-04  27.43  28.11  26.92  28.09  31146800      24.77
# 2010-01-05  28.30  29.12  28.20  28.97  28692700      25.55
# 2010-01-06  29.21  29.22  28.53  28.65  16055000      25.26
# 2010-01-07  28.63  28.80  28.18  28.72  13906600      25.33
# 2010-01-08  28.39  28.92  28.05  28.91  11656400      25.49

# %%
panl.mean()
# Out:
#            Open       High        Low      Close           Volume  Adj Close
# CBAK   1.729793   1.801296   1.670548   1.726312    117231.399046   4.791431
# CHK   24.194173  24.530962  23.802099  24.165183  14230063.910970  22.160851
# TSLA  88.219516  89.988011  86.329129  88.177227   4133400.176056  88.177227
# WTI   16.080199  16.418887  15.720723  16.069173    806965.580286  14.329173

# %%
df = panl.to_frame()
df.head()
# Out:
#                    Open   High    Low  Close    Volume  Adj Close
# Date       minor
# 2010-01-04 CBAK    2.90   2.90   2.67   2.70    456600      13.50
#            CHK    27.43  28.11  26.92  28.09  31146800      24.77
#            WTI    11.90  12.46  11.86  12.26    838800       9.82
# 2014-12-30  1.96  19.80  224.78   7.60  1.96  20.08  225.55   7.79  1.96
# 2014-12-31  1.84  19.46  223.09   7.29  1.92  19.99  225.68   7.44  1.83
#
#                    ...     Close          Volume                              \
# minor         CHK  ...      TSLA    WTI     CBAK       CHK     TSLA      WTI
# Date               ...
# 2010-01-04  26.92  ...       NaN  12.26   456600  31146800      NaN   838800
# 2010-01-05  28.20  ...       NaN  12.34  1179500  28692700      NaN   625400
# 2010-01-06  28.53  ...       NaN  12.58   633500  16055000      NaN   604700
# 2010-01-07  28.18  ...       NaN  12.45   784600  13906600      NaN   565300
# 2010-01-08  28.05  ...       NaN  12.50   797800  11656400      NaN   521100
# 2010-01-11  27.73  ...       NaN  12.40   510100  15041300      NaN  1177400
# 2010-01-12  27.17  ...       NaN  11.90   383800  13724400      NaN   921200
# 2010-01-13  26.92  ...       NaN  11.42   276000  11103000      NaN  1778300
# 2010-01-14  27.52  ...       NaN  11.80   186800  16784700      NaN   890300
# 2010-01-15  27.25  ...       NaN  11.10   226100  18228400      NaN  2163400
# 2010-01-19  27.50  ...       NaN  10.94   177700  11046900      NaN  1172500
# 2010-01-20  27.36  ...       NaN  10.39   244900  10609400      NaN  1790100
# 2010-01-21  27.17  ...       NaN  10.14   975400  17429300      NaN  1698200
# 2010-01-22  26.48  ...       NaN   9.86   285800  16902900      NaN  1083900
# 2010-01-25  26.72  ...       NaN   9.80   204700   9878300      NaN  1153700
# 2010-01-26  26.32  ...       NaN   9.75   251300  10671500      NaN   818300
# 2010-01-27  25.26  ...       NaN   9.65   232300  18175600      NaN   623700
# 2010-01-28  25.03  ...       NaN   9.32   313900  18972900      NaN   976200
# 2010-01-29  24.64  ...       NaN   8.91   262200  16185400      NaN  1670900
# 2010-02-01  25.08  ...       NaN   9.10   341200  11230500      NaN  1303200
# 2010-02-02  25.59  ...       NaN   9.27   241400   8428500      NaN  1123900
# 2010-02-03  25.68  ...       NaN   9.12   176200   7447700      NaN   639100
# 2010-02-04  24.13  ...       NaN   8.59   209800  15710200      NaN   966900
# 2010-02-05  23.56  ...       NaN   8.67   219600  17783100      NaN  1042400
# 2010-02-08  24.15  ...       NaN   8.52    70500  10424900      NaN   546800
# 2010-02-09  24.02  ...       NaN   8.59   583500  12256200      NaN   485000
# 2010-02-10  23.85  ...       NaN   8.65   133300   8410700      NaN   452300
# 2010-02-11  24.25  ...       NaN   9.04    90000  10089200      NaN   522300
# 2010-02-12  24.31  ...       NaN   9.18    75100  11025100      NaN   983500
# 2010-02-16  25.48  ...       NaN   9.43   144300   9608900      NaN   596400
# ...           ...  ...       ...    ...      ...       ...      ...      ...
# 2014-11-18  22.73  ...    257.70   9.65    35200   9034300  4473000  1766600
# 2014-11-19  22.86  ...    247.74   9.46    42300  11028300  7914500  1514100
# 2014-11-20  23.02  ...    248.71  10.00    39300   9860700  3584000  1173000
# 2014-11-21  23.82  ...    242.78  10.69    50300  13412000  7481800  1767700
# 2014-11-24  23.73  ...    246.72  10.18    42200   8262100  4786500  1474900
# 2014-11-25  23.40  ...    248.09   9.81    34300   9974000  3155900  1504300
# 2014-11-26  22.90  ...    248.44   9.19     6800  10396800  1981200  2208000
# 2014-11-28  20.24  ...    244.52   7.53    84500  14288300  2119700  2132200
# 2014-12-01  19.49  ...    231.64   7.12    86100  20045400  8595400  2814500
# 2014-12-02  19.49  ...    231.43   6.78    50500  11501200  5867700  2531600
# 2014-12-03  19.67  ...    229.30   7.06    47400  14480100  5295500  2549700
# 2014-12-04  19.28  ...    228.28   6.51    79800   8899000  3855600  2820500
# 2014-12-05  19.14  ...    223.71   6.49    43700  10932800  6057000  2798600
# 2014-12-08  18.00  ...    214.36   5.82    41700  18133400  9203900  3043700
# 2014-12-09  17.89  ...    216.89   6.62    36100  11200900  9352200  2880500
# 2014-12-10  16.90  ...    209.84   5.97    25100  19946600  7298100  2148400
# 2014-12-11  16.63  ...    208.88   5.90    15500  13201000  6680600  1475200
# 2014-12-12  16.41  ...    207.00   5.68    51000  22559200  7157900  2216100
# 2014-12-15  17.10  ...    204.04   5.49    16200  22666300  5193500  2686700
# 2014-12-16  16.90  ...    197.81   5.83   121300  15299800  8408000  2407700
# 2014-12-17  17.52  ...    205.82   6.74    20500  24238800  7354100  3072800
# 2014-12-18  18.48  ...    218.26   6.73    48100  17912400  7459200  3293100
# 2014-12-19  18.65  ...    219.29   7.63    39000  23379500  6890600  5775100
# 2014-12-22  18.30  ...    222.60   7.52    24100  20190800  4799400  2758500
# 2014-12-23  19.20  ...    220.97   7.67   103100  21904100  4505700  2856200
# 2014-12-24  19.60  ...    222.26   7.55     7400   7460400  1332200  1098500
# 2014-12-26  19.50  ...    227.82   7.49    24900   7746500  3299500  1154900
# 2014-12-29  19.80  ...    225.71   7.72    42100   9096500  2802500  1592400
# 2014-12-30  19.51  ...    222.13   7.43        0   9820900    91500  1106000
# 2014-12-31  19.23  ...    222.41   7.34    76200  10677900  2297500  1434700
#
#            Adj Close
# minor           CBAK    CHK    TSLA    WTI
# Date
# 2010-01-04     13.50  24.77     NaN   9.82
# 2010-01-05     14.25  25.55     NaN   9.89
# 2010-01-06     14.40  25.26     NaN  10.08
# 2010-01-07     14.50  25.33     NaN   9.98
# 2010-01-08     15.20  25.49     NaN  10.02
# 2010-01-11     15.30  24.69     NaN   9.94
# 2010-01-12     14.60  24.32     NaN   9.54
# 2010-01-13     14.70  24.53     NaN   9.15
# 2010-01-14     14.60  24.40     NaN   9.46
# 2010-01-15     14.25  24.61     NaN   8.90
# 2010-01-19     14.35  24.88     NaN   8.77
# 2010-01-20     13.90  24.39     NaN   8.33
# 2010-01-21     14.00  23.97     NaN   8.13
# 2010-01-22     13.50  23.47     NaN   7.90
# 2010-01-25     13.05  23.77     NaN   7.85
# 2010-01-26     12.50  23.40     NaN   7.81
